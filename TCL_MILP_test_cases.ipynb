# %% [markdown]
# # Thermostatically Controlled Load using Mixed-Integer Linear Programming Testing

# %%
import numpy as np
from TCL_MILP import TCL_MILP

import matplotlib.pyplot as plt

# %% [markdown]
# ## Test Case 1

# %%
pr = np.array([10, 20, 30, 40, 50])
dt = 10
P = 20
c_water = 0.073
m = 50
temp_up = 25
temp_o = 25
temp_req = 37
temp_en = np.array([25, 20, 18, 15, 15])
di = np.array([25, 27, 28, 22, 25])

# MILP Solution
solution = TCL_MILP(dt, pr, P, c_water, m, temp_up, temp_o, temp_req, temp_en, di)

# Plot
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[0][:], 'x-')
ax.plot(solution[2][:], 'v-')
ax.plot(solution[3][:], 'm-')
ax.plot(solution[1][:], 'p-')
ax.text(4.5,0,'power status',color='orange')
ax.text(4.5,10,'price',color='blue')
ax.text(4.5,20,'lower bound',color='red')
ax.text(4.5,30,'optimal energy',color='purple')
ax.text(4.5,40,'upper bound',color='green')
ax.plot()
ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# 5
# Optimize a model with 10 rows, 5 columns and 30 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+01, 1e+01]
#   Objective range  [1e+02, 5e+02]
#   Bounds range     [2e+01, 2e+01]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 10 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.4750000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective  5.475000000e+03
#
#
# ************************Result************************
# Power Status:  [ 2.19    3.3507  3.8836  3.5332  4.015 ]
# Total Cost:  5475.0

# %% [markdown]
# Comments: 1) power at each status is within limit. 2) Energy at each time step satisfies constraints.(This is the special case as initial temperature and upper limit value are set the same, so that the upper bound and lower bound of energy are the same and then there is only one optimal value)

# %% [markdown]
# ## Test Case 2

# %%
# Compared with Case 1, only tmp_o changes
pr = np.array([10, 20, 30, 40, 50])
dt = 10
P = 20
c_water = 0.073
m = 50
temp_up = 25
temp_o = 20
temp_req = 37
temp_en = np.array([25, 20, 18, 15, 15])
di = np.array([25, 27, 28, 22, 25])

# MILP Solution
solution = TCL_MILP(dt, pr, P, c_water, m, temp_up, temp_o, temp_req, temp_en, di)

# Plot
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[0][:], 'x-')
ax.plot(solution[2][:], 'v-')
ax.plot(solution[3][:], 'm-')
ax.plot(solution[1][:], 'p-')
ax.text(4.5,0,'power status',color='orange')
ax.text(4.5,10,'price',color='blue')
ax.text(4.5,20,'lower bound',color='red')
ax.text(4.5,30,'optimal energy',color='purple')
ax.text(4.5,40,'upper bound',color='green')
ax.plot()
ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# 5
# Optimize a model with 10 rows, 5 columns and 30 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+01, 1e+01]
#   Objective range  [1e+02, 5e+02]
#   Bounds range     [2e+01, 2e+01]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 5 rows, 7 columns, 14 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3233024e+03   1.035348e+01   0.000000e+00      0s
#        5    4.7450000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.02 seconds
# Optimal objective  4.745000000e+03
#
#
# ************************Result************************
# Power Status:  [ 4.015   3.3507  3.8836  3.5332  2.19  ]
# Total Cost:  4744.999999999999

# %% [markdown]
# Comments: 1) Power at each status is within limit. 2) Energy at each time step satisfies constraints.

# %% [markdown]
# ## Test Case 3

# %%
# Compared with case 2, only the price changes
pr = np.array([50, 40, 30, 20, 10])
dt = 10
P = 20
c_water = 0.073
m = 50
temp_up = 25
temp_o = 20
temp_req = 37
temp_en = np.array([25, 20, 18, 15, 15])
di = np.array([25, 27, 28, 22, 25])

# MILP Solution
solution = TCL_MILP(dt, pr, P, c_water, m, temp_up, temp_o, temp_req, temp_en, di)

# Plot
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[0][:], 'x-')
ax.plot(solution[2][:], 'v-')
ax.plot(solution[3][:], 'm-')
ax.plot(solution[1][:], 'p-')
ax.text(4.5,0,'power status',color='orange')
ax.text(4.5,10,'price',color='blue')
ax.text(4.5,20,'lower bound',color='red')
ax.text(4.5,30,'optimal energy',color='purple')
ax.text(4.5,40,'upper bound',color='green')
ax.plot()
ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# 5
# Optimize a model with 10 rows, 5 columns and 30 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+01, 1e+01]
#   Objective range  [1e+02, 5e+02]
#   Bounds range     [2e+01, 2e+01]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 5 rows, 7 columns, 14 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0519424e+03   1.035348e+01   0.000000e+00      0s
#        3    4.7085000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.02 seconds
# Optimal objective  4.708500000e+03
#
#
# ************************Result************************
# Power Status:  [ 2.19    3.3507  3.8836  3.5332  4.015 ]
# Total Cost:  4708.499999999999

# %% [markdown]
# Comments: 1) Power at each status is within limit. 2) Energy at each time step satisfies constraints.

# %% [markdown]
# ## Test Case 4

# %%
# Compared with case 2 & 3, only the price changes
pr = np.array([10, 50, 10, 50, 10])
dt = 10
P = 20
c_water = 0.073
m = 50
temp_up = 25
temp_o = 20
temp_req = 37
temp_en = np.array([25, 20, 18, 15, 15])
di = np.array([25, 27, 28, 22, 25])

# MILP Solution
solution = TCL_MILP(dt, pr, P, c_water, m, temp_up, temp_o, temp_req, temp_en, di)

# Plot
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[0][:], 'x-')
ax.plot(solution[2][:], 'v-')
ax.plot(solution[3][:], 'm-')
ax.plot(solution[1][:], 'p-')
ax.text(4.5,0,'power status',color='orange')
ax.text(4.5,10,'price',color='blue')
ax.text(4.5,20,'lower bound',color='red')
ax.text(4.5,30,'optimal energy',color='purple')
ax.text(4.5,40,'upper bound',color='green')
ax.plot()
ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# 5
# Optimize a model with 10 rows, 5 columns and 30 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+01, 1e+01]
#   Objective range  [1e+02, 5e+02]
#   Bounds range     [2e+01, 2e+01]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.02s
# Presolved: 5 rows, 7 columns, 14 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3699041e+03   1.035348e+01   0.000000e+00      0s
#        4    2.9908100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.02 seconds
# Optimal objective  2.990810000e+03
#
#
# ************************Result************************
# Power Status:  [ 4.015   1.5257  5.7086  1.7082  4.015 ]
# Total Cost:  2990.809999999999

# %% [markdown]
# Comments: 1) Power at each status is within limit. 2) Energy at each time step satisfies constraints.

# %% [markdown]
# ## Test Case 5

# %%
# Compared with case 4, only the power limit differs
pr = np.array([10, 50, 10, 50, 10])
dt = 10
P = 5
c_water = 0.073
m = 50
temp_up = 25
temp_o = 20
temp_req = 37
temp_en = np.array([25, 20, 18, 15, 15])
di = np.array([25, 27, 28, 22, 25])

# MILP Solution
solution = TCL_MILP(dt, pr, P, c_water, m, temp_up, temp_o, temp_req, temp_en, di)

# Plot
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[0][:], 'x-')
ax.plot(solution[2][:], 'v-')
ax.plot(solution[3][:], 'm-')
ax.plot(solution[1][:], 'p-')
ax.text(4.5,0,'power status',color='orange')
ax.text(4.5,10,'price',color='blue')
ax.text(4.5,20,'lower bound',color='red')
ax.text(4.5,30,'optimal energy',color='purple')
ax.text(4.5,40,'upper bound',color='green')
ax.plot()
ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# 5
# Optimize a model with 10 rows, 5 columns and 30 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+01, 1e+01]
#   Objective range  [1e+02, 5e+02]
#   Bounds range     [5e+00, 5e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 5 rows, 7 columns, 14 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6650082e+03   9.615725e+00   0.000000e+00      0s
#        3    3.2742500e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds
# Optimal objective  3.274250000e+03
#
#
# ************************Result************************
# Power Status:  [ 4.015   2.2343  5.      1.7082  4.015 ]
# Total Cost:  3274.2499999999995

# %% [markdown]
# Comments: 1) Power at each status is within limit. 2) Energy at each time step satisfies constraints.

# %% [markdown]
# ## Test Case 6

# %%
# Compared with case 4, only the required temperature differs
pr = np.array([10, 50, 10, 50, 10])
dt = 10
P = 10
c_water = 0.073
m = 50
temp_up = 25
temp_o = 20
temp_req = 60
temp_en = np.array([25, 20, 18, 15, 15])
di = np.array([25, 27, 28, 22, 25])


# MILP Solution
solution = TCL_MILP(dt, pr, P, c_water, m, temp_up, temp_o, temp_req, temp_en, di)

# Plot
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[0][:], 'x-')
ax.plot(solution[2][:], 'v-')
ax.plot(solution[3][:], 'm-')
ax.plot(solution[1][:], 'p-')
ax.text(4.5,0,'power status',color='orange')
ax.text(4.5,20,'price',color='blue')
ax.text(4.5,40,'lower bound',color='red')
ax.text(4.5,60,'optimal energy',color='purple')
ax.text(4.5,80,'upper bound',color='green')
ax.plot()
ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# 5
# Optimize a model with 10 rows, 5 columns and 30 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+01, 1e+01]
#   Objective range  [1e+02, 5e+02]
#   Bounds range     [1e+01, 1e+01]
#   RHS range        [6e+01, 4e+02]
# Presolve removed 7 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 3 rows, 6 columns, 11 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.7364707e+03   1.125316e+01   0.000000e+00      0s
#        2    8.5779000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.02 seconds
# Optimal objective  8.577900000e+03
#
#
# ************************Result************************
# Power Status:  [  8.2125   6.059   10.       5.8118   8.2125]
# Total Cost:  8577.899999999998

# %% [markdown]
# Comments: 1) Power at each status is within limit. 2) Energy at each time step satisfies constraints.

# %% [markdown]
# ## Test Case 7

# %%
# Compared with case 4, only the price changes
pr = np.array([10, 50, 1, 70, 15])
dt = 10
P = 20
c_water = 0.073
m = 50
temp_up = 25
temp_o = 20
temp_req = 37
temp_en = np.array([25, 20, 18, 15, 15])
di = np.array([25, 27, 28, 22, 25])

# MILP Solution
solution = TCL_MILP(dt, pr, P, c_water, m, temp_up, temp_o, temp_req, temp_en, di)

# Plot
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[0][:], 'x-')
ax.plot(solution[2][:], 'v-')
ax.plot(solution[3][:], 'm-')
ax.plot(solution[1][:], 'p-')
ax.text(4.5,0,'power status',color='orange')
ax.text(4.5,10,'price',color='blue')
ax.text(4.5,20,'lower bound',color='red')
ax.text(4.5,30,'optimal energy',color='purple')
ax.text(4.5,40,'upper bound',color='green')
ax.plot()
ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# 5
# Optimize a model with 10 rows, 5 columns and 30 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+01, 1e+01]
#   Objective range  [1e+01, 7e+02]
#   Bounds range     [2e+01, 2e+01]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 5 rows, 7 columns, 14 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1849054e+03   1.035348e+01   0.000000e+00      0s
#        4    3.0194260e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds
# Optimal objective  3.019426000e+03
#
#
# ************************Result************************
# Power Status:  [ 4.015   1.5257  5.7086  1.7082  4.015 ]
# Total Cost:  3019.425999999999

# %% [markdown]
# Comments: 1) Power at each status is within limit. 2) Energy at each time step satisfies constraints.
