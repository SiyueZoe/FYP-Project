# %% [markdown]
# # Interruptible Load with EM using Linear Programming Testing

# %%
import numpy as np
from IL_LP_with_EM import IL_LP_with_EM

import matplotlib.pyplot as plt

# %% [markdown]
# ## Test Case 1

# %%
dt = 10
pr = np.array([10,20,30,40,50,60])
P = 20
E = 900
T_off = 4
small_const = 0.0001

# LP solution
solution = IL_LP_with_EM(dt, pr, P, E, T_off, small_const)
print('Total Cost: ', solution[0])
print('Power statuses: ', solution[1][:])
print('On/Off status: ', solution[2][:])

# Plot the price distribution
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[1][:], 'x-')
ax.plot()

ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# Total Cost:  25000.0
# Power statuses:  [ 20.  20.  20.  20.  10.   0.]
# On/Off status:  [ 1.   1.   1.   1.   0.5  0. ]

# %% [markdown]
# Comments: 1) The sum of energy is correct. 2) This violates the connection between x and y. 3) Ancillary binary y follows the requirement of switching on/off.

# %% [markdown]
# ## Test Case 2

# %%
dt = 10
pr = np.array([10,50,10,50,50])
P = 20
E = 500
T_off = 2
small_const = 0.0001

# LP solution
solution = IL_LP_with_EM(dt, pr, P, E, T_off, small_const)
print('Total Cost: ', solution[0])
print('Power statuses: ', solution[1][:])
print('On/Off status: ', solution[2][:])

# Plot the price distribution
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[1][:], 'x-')
ax.plot()

ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# Total Cost:  9000.0
# Power statuses:  [ 20.  10.  20.   0.   0.]
# On/Off status:  [ 1.  1.  1.  0.  0.]

# %% [markdown]
# Comments: 1) The sum of energy is correct. 2) This follows the connection between x and y. 3) Ancillary binary y follows the requirement of switching on/off.

# %% [markdown]
# ## Test Case 3

# %%
dt = 10
pr = np.array([10,50,2,10,50,1])
P = 13
E = 90
T_off = 2
small_const = 0.0001

# LP solution
solution = IL_LP_with_EM(dt, pr, P, E, T_off, small_const)
print('Total Cost: ', solution[0])
print('Power statuses: ', solution[1][:])
print('On/Off status: ', solution[2][:])

# Plot the price distribution
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[1][:], 'x-')
ax.plot()

ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# Total Cost:  90.0
# Power statuses:  [ 0.  0.  0.  0.  0.  9.]
# On/Off status:  [ 0.          0.          0.          0.          0.          0.69230769]

# %% [markdown]
# Comments: 1) The sum of energy is correct. 2) This violates the connection between x and y. 3) Ancillary binary y follows the requirement of switching on/off.

# %% [markdown]
# ## Test Case 4

# %%
dt = 10
pr = np.array([1,50,1,10,10])
P = 20
E = 500
T_off = 2
small_const = 0.0001

# LP solution
solution = IL_LP_with_EM(dt, pr, P, E, T_off, small_const)
print('Total Cost: ', solution[0])
print('Power statuses: ', solution[1][:])
print('On/Off status: ', solution[2][:])

# Plot the price distribution
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[1][:], 'x-')
ax.plot()

ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# Total Cost:  1400.04
# Power statuses:  [  2.00000000e+01   1.00000000e-04   2.00000000e+01   9.99990000e+00
#    0.00000000e+00]
# On/Off status:  [ 1.        1.        1.        0.499995  0.      ]

# %% [markdown]
# Comments: 1) The sum of energy is correct. 2) This violates the connection between x and y. 3) Ancillary binary y follows the requirement of switching on/off.

# %%
dt = 10
pr = np.array([1,40,1,30,60])
P = 20
E = 500
T_off = 2
small_const = 0.0001

# LP solution
solution = IL_LP_with_EM(dt, pr, P, E, T_off, small_const)
print('Total Cost: ', solution[0])
print('Power statuses: ', solution[1][:])
print('On/Off status: ', solution[2][:])

# Plot the price distribution
fig, ax = plt.subplots()
ax.plot(pr, 'o-')
ax.plot(solution[1][:], 'x-')
ax.plot()

ax.set(xlabel='Time', ylabel='Price, $ (dots)/ \n Consumption, Wh (crosses)',
       title='Prices and Load Scheduling');
# Out:
# Total Cost:  3400.01
# Power statuses:  [  2.00000000e+01   1.00000000e-04   2.00000000e+01   9.99990000e+00
#    0.00000000e+00]
# On/Off status:  [ 1.        1.        1.        0.499995  0.      ]
